# %%
import pandas as pd
import seaborn as sl
import matplotlib.pyplot as plt
import numpy as np
import sys
import math

df = pd.read_excel("/content/drive/MyDrive/tcs project/Data_set.xlsx")

# %%
df.shape
# Out:
# (30000, 19)

# %%
df.columns
# Out:
# Index(['Acc_ID', 'Limit', 'SEX', 'EDUCATION', 'MARRIAGE', 'Debt', 'BILL_AMT1',
#        'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
#        'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df['default payment next month'].unique()
# Out:
# array([0, 1])

# %%
defaults = df['default payment next month']

# %%
num_defaults = sum(defaults)

# %%
df.dtypes
# Out:
# Acc_ID                          int64
# Limit                           int64
# SEX                             int64
# EDUCATION                       int64
# MARRIAGE                        int64
# Debt                          float64
# BILL_AMT1                       int64
# BILL_AMT2                       int64
# BILL_AMT3                       int64
# BILL_AMT4                       int64
# BILL_AMT5                       int64
# BILL_AMT6                       int64
# PAY_AMT1                        int64
# PAY_AMT2                        int64
# PAY_AMT3                        int64
# PAY_AMT4                        int64
# PAY_AMT5                        int64
# PAY_AMT6                        int64
# default payment next month      int64
# dtype: object

# %%
defaults.dtypes
# Out:
# dtype('int64')

# %%
num_defaults
# Out:
# 6636

# %%
default_rate =  defaults /df['default payment next month'].count()

# %%
default_rate
# Out:
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
#            ...
# 29995    0.000000
# 29996    0.000000
# 29997    0.000000
# 29998    0.000000
# 29999    0.000033
# Name: default payment next month, Length: 30000, dtype: float64

# %%
default_counts = dt['default payment next month'].value_counts()

# %%
default_counts
# Out:
# 0    23364
# 1     6636
# Name: default payment next month, dtype: int64

# %%
default_rate = default_counts[1] / dt.shape[0]

# %%
default_rate
# Out:
# 0.2212

# %%
dt
# Out:
#        Acc_ID   Limit  SEX  EDUCATION  MARRIAGE  Debt  BILL_AMT1  BILL_AMT2  \
# 0           1   70100    1          3         1  44.0      26554      28213
# 1           2  110500    2          3         1  37.0     114098     109614
# 2           3  100300    1          1         1  42.0      89141      86045
# 3           4  180400    2          2         2  47.0       1909       2458
# 4           5  240300    2          1         2  38.0       7288       5271
# ...       ...     ...  ...        ...       ...   ...        ...        ...
# 29995   29996   50400    1          3         2  47.0      46847      48361
# 29996   29997   30100    2          3         1  39.0      26413      27583
# 29997   29998  340300    2          1         2  40.0     250478     244602
# 29998   29999  300100    2          2         1  37.0     141491      79479
# 29999   30000   50200    1          2         1  47.0      47933      48910
#
# ...

# %%
df = df[(df['BILL_AMT6'] > 0) & (df['Limit'] > 0) & (df['Debt'] > 31)]

# %%
df
# Out:
#        Acc_ID   Limit  SEX  EDUCATION  MARRIAGE  Debt  BILL_AMT1  BILL_AMT2  \
# 0           1   70100    1          3         1  44.0      26554      28213
# 1           2  110500    2          3         1  37.0     114098     109614
# 2           3  100300    1          1         1  42.0      89141      86045
# 3           4  180400    2          2         2  47.0       1909       2458
# 4           5  240300    2          1         2  38.0       7288       5271
# ...       ...     ...  ...        ...       ...   ...        ...        ...
# 29994   29995   30400    2          2         1  39.0      28756      23824
# 29996   29997   30100    2          3         1  39.0      26413      27583
# 29997   29998  340300    2          1         2  40.0     250478     244602
# 29998   29999  300100    2          2         1  37.0     141491      79479
# 29999   30000   50200    1          2         1  47.0      47933      48910
#
# ...

# %%
df.shape
# Out:
# (16434, 19)

# %%
new_counts = df['default payment next month'].value_counts()

# %%
new_counts
# Out:
# 0    12900
# 1     3534
# Name: default payment next month, dtype: int64

# %%
new_rate = new_counts[1]/df.shape[0]

# %%
new_rate
# Out:
# 0.21504198612632347

# %%
df['payment ratio'] = df['PAY_AMT6'] / df['BILL_AMT6']

# %%
df.head()
# Out:
#    Acc_ID   Limit  SEX  EDUCATION  MARRIAGE  Debt  BILL_AMT1  BILL_AMT2  \
# 0       1   70100    1          3         1  44.0      26554      28213
# 1       2  110500    2          3         1  37.0     114098     109614
# 2       3  100300    1          1         1  42.0      89141      86045
# 3       4  180400    2          2         2  47.0       1909       2458
# 4       5  240300    2          1         2  38.0       7288       5271
#
#    BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      28651      30670      31133      31965      2401      1200      2820
# 1      87380      49525      49225      48968      5623      9860      1741
# 2      71916      65693      63835      18660         4      3515      6300
# 3       7005       3064       2158       9331      2460      6997      3064
# 4       5121       7113       7113       4178      1266      1000      2000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month  payment ratio
# ...

# %%
df['payment ratio'].describe()
# Out:
# count    16434.000000
# mean         1.704718
# std         28.105751
# min          0.000000
# 25%          0.034481
# 50%          0.047313
# 75%          0.350732
# max       2643.330000
# Name: payment ratio, dtype: float64

# %%
df['credit_limit'] = df['Limit']/1000

# %%
df['credit_limit'].describe()
# Out:
# count    16434.000000
# mean       186.878866
# std        137.205945
# min         10.100000
# 25%         70.300000
# 50%        160.400000
# 75%        270.100000
# max       1000.500000
# Name: credit_limit, dtype: float64

# %%
logic= df['PAY_AMT6']/ df['BILL_AMT6']

# %%
logic
# Out:
# 0        0.040669
# 1        0.038678
# 2        0.000000
# 3        0.000000
# 4        1.196745
#            ...
# 29994    0.048325
# 29996    0.000000
# 29997    0.038084
# 29998    0.097312
# 29999    0.065304
# Length: 16434, dtype: float64

# %%
fig=plt.figure(figsize =(12,6))
plt.scatter(logic,df['payment ratio'],color='r')

# %%
df['payment_ratio_bins'] = pd.cut(df['payment ratio'], bins=5)

# %%
default_rates1 = df.groupby('payment_ratio_bins')['default payment next month'].mean()

# %%
default_rates1
# Out:
# payment_ratio_bins
# (-2.643, 528.666]       0.215047
# (528.666, 1057.332]     0.333333
# (1057.332, 1585.998]         NaN
# (1585.998, 2114.664]    0.000000
# (2114.664, 2643.33]     0.000000
# Name: default payment next month, dtype: float64

# %%
fig = plt.figure(figsize=(12,6))
plt.scatter(df['Limit'],df['credit_limit'])

# %%
df['Limit_bin'] = pd.cut(df['Limit'], bins=5, labels=False)

# %%
# Compute the default rate for each bin
default_rate = df.groupby('Limit_bin')['default payment next month'].mean()

# %%
default_rate
# Out:
# Limit_bin
# 0    0.265124
# 1    0.139003
# 2    0.115091
# 3    0.060606
# 4    0.000000
# Name: default payment next month, dtype: float64

# %%
fig = plt.figure(figsize=(12,6))
plt.scatter(df['Acc_ID'],df['Debt'])

# %%
df['Debt_bin'] = pd.cut(df['Debt'], bins=5, labels=False)

# %%
# Compute the default rate for each bin
default_rate = df.groupby('Debt_bin')['default payment next month'].mean()

print(default_rate)
# Out:
# Debt_bin
# 0    0.200220
# 1    0.228495
# 2    0.247300
# 3    0.234513
# 4    0.222222
# Name: default payment next month, dtype: float64
